# %%
BASE_ID = "unsloth/Llama-3.2-3B-Instruct"

# %%
from unsloth import FastLanguageModel
import torch

max_seq_length = 2048 # Can increase for longer RL output
lora_rank = 128        # Larger rank = smarter, but slower
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = BASE_ID,
    load_in_4bit = False,
    max_seq_length = max_seq_length,
)
# Out:
# Unsloth: AMD currently is not stable with 4bit bitsandbytes. Disabling for now.
# ==((====))==  Unsloth 2025.10.9: Fast Llama patching. Transformers: 4.56.2.
#    \\   /|    AMD Radeon Graphics. Num GPUs = 1. Max memory: 191.688 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+rocm6.4. ROCm Toolkit: 6.4.43482-0f2d60242. Triton: 3.4.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.32.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards: 100% 2/2 [00:02<00:00,  1.21s/it]

# %%
model_policy = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ], # Remove QKVO if out of memory
    lora_alpha = lora_rank,
    use_gradient_checkpointing = "unsloth", # Enable long context finetuning
    random_state = 3407,
)
model_policy.print_trainable_parameters()
# Out:
# trainable params: 194,510,848 || all params: 3,407,260,672 || trainable%: 5.7087

# %%
import os, sys, subprocess

working_directory = "/shared-docker/OpenEnv"  # repo root containing src/
port = "8050"
keepalive = "1000"

cmd = [
    sys.executable, "-m", "uvicorn",
    "envs.cartpole_env.server.app:app",  # <— our new app path
    "--host", "0.0.0.0",
    "--port", port,
    "--timeout-keep-alive", keepalive,
]

env = {
    **os.environ,
    "PYTHONPATH": f"{working_directory}/src",

    # CartPole knobs (analogous to OPENSPIEL_*):
    "CARTPOLE_ENV_ID": "CartPole-v1",
    "CARTPOLE_SEED": "123",
    "CARTPOLE_MAX_EPISODE_STEPS": "1000",
    "CARTPOLE_RENDER_MODE": "none",  # or "rgb_array"
}

#proc = subprocess.Popen(cmd, env=env, cwd=working_directory,
#                        stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

#print("CartPole server starting at http://localhost:8020 … PID:", proc.pid)

# %%
import httpx, time
time.sleep(1)
r = httpx.post("http://localhost:8050/reset", json={}); print(r.json())
# Out:
# INFO:httpx: HTTP Request: POST http://localhost:8050/reset "HTTP/1.1 200 OK"
# {'observation': {'state': [-0.45442235469818115, 0.0], 'legal_actions': [-1.0, 1.0], 'episode_length': 0, 'total_reward': 0.0}, 'reward': 0.0, 'done': False}

# %%
import requests
import time
time.sleep(5) # Wait 5 seconds for OpenEnv to start!
from envs.mountaincarcontinuous_environment import MountainCarContinuousEnv, MountainCarContinuousAction
import httpx

# Same shape as: OpenSpielEnv(base_url=..., request_timeout_s=...)
base_url = "http://localhost:8050"
request_timeout_s = 1000  # seconds

openenv_process = openenv_process = MountainCarContinuousEnv(
        base_url=base_url,
        request_timeout_s=request_timeout_s
    )
# quick smoke test
# info = openenv_process.info()

# print("CartPole info:", info)

state = openenv_process.reset()
print("reset:", state)

# step with discrete action 0/1
state = openenv_process.step(MountainCarContinuousAction(
                engine_force=0.1))
print("step:", state)
# Out:
# reset: StepResult(observation=MountainCarContinuousObservation(done=False, reward=0.0, metadata={}, state=[-0.45953240990638733, 0.0], legal_actions=[-1.0, 1.0], episode_length=0, total_reward=0.0), reward=0.0, done=False)
# step: StepResult(observation=MountainCarContinuousObservation(done=False, reward=-0.0010000000000000002, metadata={}, state=[-0.4598599374294281, -0.000327545014442876], legal_actions=[-1.0, 1.0], episode_length=1, total_reward=-0.0010000000000000002), reward=-0.0010000000000000002, done=False)

# %%
def strategy_simple(state):
    # state = [x, dx, angle, dangle]
    return 0  # left or 1 right


def build_user_prompt():
    return (
        """You are an expert MountainCarContinuous player and a precise Python code generator.

Context / How this will be used
- Your function will be called every environment step to control the entire episode of MountainCarContinuous-v0 (OpenAI Gym/Gymnasium style, continuous actions).
- The episode ends when the car reaches the goal (typically x ≥ 0.45–0.5) or when the environment hits its max step limit.
- Reward shaping encourages reaching the goal quickly while using as little engine force as possible (penalizes large |action|).

Your objective: reach the goal position as fast as possible by smartly building and exploiting momentum on the hills, while avoiding wasteful throttle.

What you must write
- A single Python function with this exact signature (no extras):
    def mountaincar_strategy(state):
- Input `state` is a list of 2 floats: [x, v]
  - x = car position (range about [-1.2, 0.6])
  - v = car velocity (range about [-0.07, 0.07])
- Output: return a **float** action in **[-1.0, 1.0]**
  - negative = throttle left, positive = throttle right, zero ≈ coasting.
  - The caller will pass this scalar to the env (wrapping into a length-1 array if needed).

Design guidance for long-horizon control
- MountainCarContinuous requires **momentum pumping**: generally apply force in the direction of current velocity to amplify swings, then **time the reversal** to crest the right hill.
- Prefer a **short, deterministic** control law (e.g., a weighted linear rule with saturating clamp to [-1, 1]).
- Add a **deadband/hysteresis** around v ≈ 0 to avoid rapid action sign flips; coasting (≈0) can be beneficial when switching directions.
- Useful heuristics:
  - If v > +ε, bias action right; if v < -ε, bias action left.
  - When far on the left (x < -0.5), allow larger left pushes to harvest momentum.
  - Near the final ascent on the right (x > -0.2), bias action right and reduce needless oscillation.
  - Optionally damp action magnitude by |v| to avoid over-throttling at high speeds.

Hard constraints
- Do not import, print, read/write files, use globals, randomness, or any I/O.
- Keep the code short and stateless; identical inputs must produce identical outputs.
- The output must be exactly one fenced code block in Python, with nothing before or after.
  - The first line inside the block must be: def mountaincar_strategy(state):
  - The last line of your entire response must be the closing backticks to clearly end the program. No trailing commentary.

Output format reminder (dummy example — do NOT copy this logic):
```
def mountaincar_strategy(state):
    x, v = state
    return 1 * x * v # dummy example
        ```
        All helper functions should be inside def mountaincar_strategy. Only output the short function `strategy`.
        """.strip())

print(build_user_prompt())
# Out:
# You are an expert MountainCarContinuous player and a precise Python code generator.
#
# Context / How this will be used
# - Your function will be called every environment step to control the entire episode of MountainCarContinuous-v0 (OpenAI Gym/Gymnasium style, continuous actions).
# - The episode ends when the car reaches the goal (typically x ≥ 0.45–0.5) or when the environment hits its max step limit.
# - Reward shaping encourages reaching the goal quickly while using as little engine force as possible (penalizes large |action|).
#
# Your objective: reach the goal position as fast as possible by smartly building and exploiting momentum on the hills, while avoiding wasteful throttle.
#
# What you must write
# - A single Python function with this exact signature (no extras):
#     def mountaincar_strategy(state):
# - Input `state` is a list of 2 floats: [x, v]
#   - x = car position (range about [-1.2, 0.6])
#   - v = car velocity (range about [-0.07, 0.07])
# - Output: return a **float** action in **[-1.0, 1.0]**
#   - negative = throttle left, positive = throttle right, zero ≈ coasting.
#   - The caller will pass this scalar to the env (wrapping into a length-1 array if needed).
#
# Design guidance for long-horizon control
# - MountainCarContinuous requires **momentum pumping**: generally apply force in the direction of current velocity to amplify swings, then **time the reversal** to crest the right hill.
# - Prefer a **short, deterministic** control law (e.g., a weighted linear rule with saturating clamp to [-1, 1]).
# - Add a **deadband/hysteresis** around v ≈ 0 to avoid rapid action sign flips; coasting (≈0) can be beneficial when switching directions.
# - Useful heuristics:
#   - If v > +ε, bias action right; if v < -ε, bias action left.
#   - When far on the left (x < -0.5), allow larger left pushes to harvest momentum.
#   - Near the final ascent on the right (x > -0.2), bias action right and reduce needless oscillation.
#   - Optionally damp action magnitude by |v| to avoid over-throttling at high speeds.
#
# Hard constraints
# - Do not import, print, read/write files, use globals, randomness, or any I/O.
# - Keep the code short and stateless; identical inputs must produce identical outputs.
# - The output must be exactly one fenced code block in Python, with nothing before or after.
#   - The first line inside the block must be: def mountaincar_strategy(state):
#   - The last line of your entire response must be the closing backticks to clearly end the program. No trailing commentary.
#
# Output format reminder (dummy example — do NOT copy this logic):
# ```
# def mountaincar_strategy(state):
#     x, v = state
#     return 1 * x * v # dummy example
#         ```
#         All helper functions should be inside def mountaincar_strategy. Only output the short function `strategy`.

# %%
def extract_function(text):
    if text.count("```") >= 2:
        first = text.find("```") + 3
        second = text.find("```", first)
        fx = text[first : second].strip()
        fx = fx[fx.find("def"):]
        if fx.startswith("def mountaincar_strategy(state):"): return fx
    return None
print(extract_function(build_user_prompt()))
# Out:
# def mountaincar_strategy(state):
#     x, v = state
#     return 1 * x * v # dummy example

# %%
# Minimal safe executor (reuse your nb's create_locked_down_function if available)
from unsloth import create_locked_down_function
from random import randint
from unsloth import check_python_modules

def _safe_compile(func_src: str):
    # Use the notebook's 'create_locked_down_function' if present
    return create_locked_down_function(func_src)

# %%
import numpy as np
from random import randint
global _PRINT_COUNTER
_PRINT_COUNTER = 0

def mc_simple_reward(s, a, r_env):
    """
    Simple shaping for MountainCarContinuous using only (state, action, env reward).
      s: (x, v)      # position, velocity
      a: float       # throttle in [-1, 1]
      r_env: float   # environment reward at this step
    Returns: float
    """
    import math
    x, v = float(s[0]), float(s[1])

    # Terrain geometry from x
    height = math.sin(3.0 * x)          # in [-1, 1]  (higher is better)
    slope  = 3.0 * math.cos(3.0 * x)    # proportional to uphill direction

    # ---- small, interpretable weights (tune if needed) ----
    w_height   = 0.5    # prefer higher positions overall
    w_push     = 0.20   # reward pushing in uphill direction (a * slope)
    w_synergy  = 0.06   # action aligned with current velocity (a * v)
    w_slow     = 0.10   # gently slow near crests (gate * v^2)
    time_cost  = 0.01   # discourage dithering
    effort_c   = 0.0005 # tiny control cost
    eps_a      = 0.04   # "idle" action band
    v_idle     = 0.02   # moving but not actuating -> penalize
    idle_pen   = 0.02

    # 1) Positional progress: higher is better (no goal hardcoding)
    progress = w_height * height

    # 2) Push uphill: align throttle with uphill direction from slope
    #    - On left hill (slope < 0) pushing left (a<0) is rewarded to build momentum
    #    - On right hill (slope > 0) pushing right (a>0) is rewarded to finish
    push_uphill = w_push * (a * slope)

    # 3) Synergy: using throttle with your current motion helps build momentum
    synergy = w_synergy * (a * v)

    # 4) Near-crest slowdown: penalize kinetic energy more as height → crest (h≈1)
    crest_gate = 0.5 * (height + 1.0)   # maps [-1,1] -> [0,1]
    slow_near_crest = w_slow * crest_gate * (v * v)

    # 5) Anti-idle: if action ~0 while moving OR terrain is steep, penalize
    steep = abs(slope) > 0.5
    idle = idle_pen if (abs(a) < eps_a and (abs(v) > v_idle or steep)) else 0.0

    shaped = (
        r_env
        + progress
        + push_uphill
        + synergy
        - slow_near_crest
        - time_cost
        - effort_c * (a * a)
        - idle
    )
    return float(shaped)
    
    
def execute_strategy(strategy_fn, initial_state, max_steps):
    """Run strategy on CartPole server until done or step limit.
       Returns (steps_survived, done_flag)."""
    steps = 0
    done = False
    state = initial_state
    reward = 0
    while not done and steps < max_steps:
        # print("try strategy")
        a = strategy_fn(state.observation.state)
        # print(a)
        if a < -1 :
            # clamp invalid actions
            a = -1 
        if a > 1:
            a = 1
        res = openenv_process.step(MountainCarContinuousAction(
                engine_force=a))
        reward += mc_simple_reward(state.observation.state, a, res.reward)
        done = bool(res.done)
        steps += 1
    return reward, steps, done


def function_works(completions, **kwargs):
    scores = []
    for completion in completions:
        score = 0
        response = completion[0]["content"]
        function = extract_function(response)
        if function is not None:
            ok, info = check_python_modules(function)
        if function is None or "error" in info:
            score = -2.0
        else:
            try:
                new_strategy = create_locked_down_function(function)
                score =  randint(7, 20)
            except:
                score = -0.5
        scores.append(score)
    return scores
    
def strategy_succeeds(completions, **kwargs):
    """completions: list of candidate generations (like the nb).
       Returns list[float] rewards (higher is better)."""
    global _PRINT_COUNTER
    scores = []

    # Reset the env once per candidate to a fresh start
    for completion in completions:
        try:
            # The notebook packs text like completion[0]["content"]
            response = completion[0]["content"]
        except Exception:
            scores.append(0.0); continue

        # Optional: print every 5th for debugging
        if _PRINT_COUNTER % 5 == 0:
            try:
                print(response.splitlines()[0][:120])
            except:
                print("...candidate omitted...")
        _PRINT_COUNTER += 1
        #print(response)
        # Parse the function from the text (reuse nb's helpers if present)
        try:
            func_src = extract_function(response)
            print(func_src)
            strategy_fn = _safe_compile(func_src)
        except Exception as e:
            print("Compile error:", e)
            scores.append(0.0); continue
        print(func_src)
        print(strategy_fn)
        # Rollout on CartPole
        try:
            # Fresh episode
            res0 = openenv_process.reset()
            current_state = res0
            reward, steps, finished = execute_strategy(strategy_fn, current_state, max_steps=10000)

            # Reward = steps survived (CartPole native) with mild shaping:
            # huge bonus if finished by reaching max steps (i.e., perfect 500).
            

            # print a brief trace for failing candidates occasionally
            if steps > 100 and (_PRINT_COUNTER % 7 == 0):
                print("Long episode:", steps)

            scores.append(reward - 0.1 * steps)
        except TimeoutError:
            # keep the semantics from the nb
            scores.append(-1.0)
        except Exception as e:
            # print(f"Exception = {str(e)}")
            scores.append(-3.0)

    return scores

# %%
toy = """
```
def mountaincar_strategy(state):
    # state: [x, v]
    print(state)
    x, v = state
    score = x + 0.1 * v
    return -0.5
    ```
"""




    
fn1 = extract_function(toy)

fn = _safe_compile(fn1)

s0 = openenv_process.reset();
# print(s0.observation.values[0],s0.observation.values[1],s0.observation.values[2],s0.observation.values[3])
print(fn(s0.observation.state))
done = False

reward, steps, done = execute_strategy(fn, s0, 100)
print("Toy strategy survived steps reward:", steps, reward)
# Out:
# [-0.5655260682106018, 0.0]
# -0.5
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# [-0.5655260682106018, 0.0]
# Toy strategy survived steps reward: 100 -49.35398000044859

# %%
from datasets import Dataset
dataset = Dataset.from_list([{"prompt" : [{"role": "user", "content": build_user_prompt().strip()}], "answer" : 0, "reasoning_effort": "low"}]*1000)
maximum_length = len(tokenizer.apply_chat_template([{"role": "user", "content": build_user_prompt().strip()}], add_generation_prompt = True))
print(maximum_length)
# Out:
# 690

# %%
dataset[0]
# Out:
# {'prompt': [{'content': 'You are an expert MountainCarContinuous player and a precise Python code generator.\n\nContext / How this will be used\n- Your function will be called every environment step to control the entire episode of MountainCarContinuous-v0 (OpenAI Gym/Gymnasium style, continuous actions).\n- The episode ends when the car reaches the goal (typically x ≥ 0.45–0.5) or when the environment hits its max step limit.\n- Reward shaping encourages reaching the goal quickly while using as little engine force as possible (penalizes large |action|).\n\nYour objective: reach the goal position as fast as possible by smartly building and exploiting momentum on the hills, while avoiding wasteful throttle.\n\nWhat you must write\n- A single Python function with this exact signature (no extras):\n    def mountaincar_strategy(state):\n- Input `state` is a list of 2 floats: [x, v]\n  - x = car position (range about [-1.2, 0.6])\n  - v = car velocity (range about [-0.07, 0.07])\n- Output: return a **float** action in **[-1.0, 1.0]**\n  - negative = throttle left, positive = throttle right, zero ≈ coasting.\n  - The caller will pass this scalar to the env (wrapping into a length-1 array if needed).\n\nDesign guidance for long-horizon control\n- MountainCarContinuous requires **momentum pumping**: generally apply force in the direction of current velocity to amplify swings, then **time the reversal** to crest the right hill.\n- Prefer a **short, deterministic** control law (e.g., a weighted linear rule with saturating clamp to [-1, 1]).\n- Add a **deadband/hysteresis** around v ≈ 0 to avoid rapid action sign flips; coasting (≈0) can be beneficial when switching directions.\n- Useful heuristics:\n  - If v > +ε, bias action right; if v < -ε, bias action left.\n  - When far on the left (x < -0.5), allow larger left pushes to harvest momentum.\n  - Near the final ascent on the right (x > -0.2), bias action right and reduce needless oscillation.\n  - Optionally damp action magnitude by |v| to avoid over-throttling at high speeds.\n\nHard constraints\n- Do not import, print, read/write files, use globals, randomness, or any I/O.\n- Keep the code short and stateless; identical inputs must produce identical outputs.\n- The output must be exactly one fenced code block in Python, with nothing before or after.\n  - The first line inside the block must be: def mountaincar_strategy(state):\n  - The last line of your entire response must be the closing backticks to clearly end the program. No trailing commentary.\n\nOutput format reminder (dummy example — do NOT copy this logic):\n```\ndef mountaincar_strategy(state):\n    x, v = state\n    return 1 * x * v # dummy example\n        ```\n        All helper functions should be inside def mountaincar_strategy. Only output the short function `strategy`.',
#    'role': 'user'}],
#  'answer': 0,
#  'reasoning_effort': 'low'}

# %%
max_prompt_length = maximum_length + 1 # + 1 just in case!
max_completion_length = max_seq_length - max_prompt_length

from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    temperature = 1.0,
    learning_rate = 5e-6,
    weight_decay = 0.01,
    warmup_ratio = 0.1,
    lr_scheduler_type = "linear",
    optim = "adamw_8bit",
    logging_steps = 1,
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 1, # Increase to 4 for smoother training
    num_generations = 8, # Decrease if out of memory
    max_prompt_length = max_prompt_length,
    max_completion_length = max_completion_length,
    # num_train_epochs = 1, # Set to 1 for a full training run
    max_steps = 600,
    save_steps = 100,
    report_to = "trackio", # Can use Weights & Biases, TrackIO
    output_dir = "outputs",

    # For optional training + evaluation
    # fp16_full_eval = True,
    # per_device_eval_batch_size = 4,
    # eval_accumulation_steps = 1,
    # eval_strategy = "steps",
    # eval_steps = 1,
)
# Out:
# Unsloth: We now expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 8

# %%
# For optional training + evaluation
# new_dataset = dataset.train_test_split(test_size = 0.01)

trainer = GRPOTrainer(
    model = model_policy,
    processing_class = tokenizer,
    reward_funcs = [
        function_works,
        strategy_succeeds,
    ],
    args = training_args,
    train_dataset = dataset,

    # For optional training + evaluation
    # train_dataset = new_dataset["train"],
    # eval_dataset = new_dataset["test"],
)
# Out:
# INFO:httpx: HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"

# %%
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 1,000 | Num Epochs = 1 | Total steps = 600
# O^O/ \_/ \    Batch size per device = 8 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (8 x 1 x 1) = 8
#  "-____-"     Trainable parameters = 194,510,848 of 3,407,260,672 (5.71% trained)
# * Trackio project initialized: huggingface
# * Trackio metrics logged to: /root/.cache/huggingface/trackio
# <div><iframe src="http://127.0.0.1:7860/?project=huggingface&write_token=ewKQpGk79GjvmA4KdXNNVAyM36HHv8EMCXtOC0M3jN4" width="100%" height="1000px" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# * Created new run: imaginative-robin-53
# `generation_config` default values have been modified to match model-specific defaults: {'max_length': 131072, 'temperature': 0.6, 'top_p': 0.9}. If this is not desired, please set these values explicitly.
# ```python
# def mountaincar_strategy(state):
#     x, v = state
#     if abs(v) < 0.01:
#         return 0
#     if x > 0.45:
#         return 0
#     if v > 0:
#         return min(1, max(-1, 1 + 0.05 * v))
#     if v < -0.05:
#         return min(1, max(-1, -1 - 0.05 * v))
#     if x < -0.5:
#         return min(1, max(-1, 1 - 0.01 * x))
#     if x > -0.2:
#         return min(1, max(-1, 1 + 0.01 * x))
# def mountaincar_strategy(state):
#     x, v = state
#     if abs(v) < 0.01:
#         return 0
#     if x > 0.45:
#         return 0
#     if v > 0:
#         return min(1, max(-1, 1 + 0.05 * v))
#     if v < -0.05:
#         return min(1, max(-1, -1 - 0.05 * v))
#     if x < -0.5:
#         return min(1, max(-1, 1 - 0.01 * x))
#     if x > -0.2:
#         return min(1, max(-1, 1 + 0.01 * x))
# <function mountaincar_strategy at 0x7b0b241657e0>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```uren हमल вид512 impe Small Aux objectiveotersrovलतků_indsctest誌uienourtkan deporticer023insky //茂 ::= Haut 江lacuienex
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
#     <div>
#
#       <progress value='508' max='600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [508/600 9:30:21 < 1:43:42, 0.01 it/s, Epoch 0.51/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completions / mean_length</th>
#       <th>completions / min_length</th>
#       <th>completions / max_length</th>
#       <th>completions / clipped_ratio</th>
#       <th>completions / mean_terminated_length</th>
#       <th>completions / min_terminated_length</th>
#       <th>completions / max_terminated_length</th>
#       <th>sampling / sampling_logp_difference / mean</th>
#       <th>sampling / sampling_logp_difference / max</th>
#       <th>sampling / importance_sampling_ratio / min</th>
#       <th>sampling / importance_sampling_ratio / mean</th>
#       <th>sampling / importance_sampling_ratio / max</th>
#       <th>kl</th>
#       <th>rewards / function_works / mean</th>
#       <th>rewards / function_works / std</th>
#       <th>rewards / strategy_succeeds / mean</th>
#       <th>rewards / strategy_succeeds / std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>-76.834480</td>
#       <td>211.663864</td>
#       <td>1207.625000</td>
#       <td>162.000000</td>
#       <td>1357.000000</td>
#       <td>0.875000</td>
#       <td>162.000000</td>
#       <td>162.000000</td>
#       <td>162.000000</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.000218</td>
#       <td>-0.875000</td>
#       <td>3.181981</td>
#       <td>-75.959480</td>
#       <td>214.845871</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>-75.443230</td>
#       <td>207.728836</td>
#       <td>1202.375000</td>
#       <td>120.000000</td>
#       <td>1357.000000</td>
#       <td>0.875000</td>
#       <td>120.000000</td>
#       <td>120.000000</td>
#       <td>120.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000297</td>
#       <td>-0.125000</td>
#       <td>5.303301</td>
#       <td>-75.318230</td>
#       <td>213.032120</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>-75.626846</td>
#       <td>208.248184</td>
#       <td>1198.500000</td>
#       <td>89.000000</td>
#       <td>1357.000000</td>
#       <td>0.875000</td>
#       <td>89.000000</td>
#       <td>89.000000</td>
#       <td>89.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000292</td>
#       <td>-0.625000</td>
#       <td>3.889087</td>
#       <td>-75.001846</td>
#       <td>212.137268</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>-76.436897</td>
#       <td>210.539337</td>
#       <td>1203.500000</td>
#       <td>129.000000</td>
#       <td>1357.000000</td>
#       <td>0.875000</td>
#       <td>129.000000</td>
#       <td>129.000000</td>
#       <td>129.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000281</td>
#       <td>-0.250000</td>
#       <td>4.949748</td>
#       <td>-76.186897</td>
#       <td>215.489090</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>-75.968102</td>
#       <td>209.213394</td>
#       <td>1199.000000</td>
#       <td>93.000000</td>
#       <td>1357.000000</td>
#       <td>0.875000</td>
#       <td>93.000000</td>
#       <td>93.000000</td>
#       <td>93.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000244</td>
#       <td>-0.500000</td>
#       <td>4.242640</td>
#       <td>-75.468102</td>
#       <td>213.456055</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>-76.600204</td>
#       <td>211.001236</td>
#       <td>1196.500000</td>
#       <td>73.000000</td>
#       <td>1357.000000</td>
#       <td>0.875000</td>
#       <td>73.000000</td>
#       <td>73.000000</td>
#       <td>73.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000314</td>
#       <td>-0.125000</td>
#       <td>5.303301</td>
#       <td>-76.475204</td>
#       <td>216.304535</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>-78.035172</td>
#       <td>215.059937</td>
#       <td>1196.125000</td>
#       <td>70.000000</td>
#       <td>1357.000000</td>
#       <td>0.875000</td>
#       <td>70.000000</td>
#       <td>70.000000</td>
#       <td>70.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000279</td>
#       <td>-0.375000</td>
#       <td>4.596194</td>
#       <td>-77.660172</td>
#       <td>219.656143</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>-76.602638</td>
#       <td>211.008133</td>
#       <td>1205.875000</td>
#       <td>148.000000</td>
#       <td>1357.000000</td>
#       <td>0.875000</td>
#       <td>148.000000</td>
#       <td>148.000000</td>
#       <td>148.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000363</td>
#       <td>0.250000</td>
#       <td>6.363961</td>
#       <td>-76.852638</td>
#       <td>217.372086</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>-75.457695</td>
#       <td>207.769730</td>
#       <td>1202.375000</td>
#       <td>120.000000</td>
#       <td>1357.000000</td>
#       <td>0.875000</td>
#       <td>120.000000</td>
#       <td>120.000000</td>
#       <td>120.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000345</td>
#       <td>0.750000</td>
#       <td>7.778175</td>
#       <td>-76.207695</td>
#       <td>215.547913</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>-77.340515</td>
#       <td>213.095154</td>
#       <td>1195.000000</td>
#       <td>61.000000</td>
#       <td>1357.000000</td>
#       <td>0.875000</td>
#       <td>61.000000</td>
#       <td>61.000000</td>
#       <td>61.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000479</td>
#       <td>-0.250000</td>
#       <td>4.949748</td>
#       <td>-77.090515</td>
#       <td>218.044907</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>-78.027222</td>
#       <td>215.037445</td>
#       <td>1197.375000</td>
#       <td>80.000000</td>
#       <td>1357.000000</td>
#       <td>0.875000</td>
#       <td>80.000000</td>
#       <td>80.000000</td>
#       <td>80.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000624</td>
#       <td>-0.500000</td>
#       <td>4.242640</td>
#       <td>-77.527222</td>
#       <td>219.280106</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>-99.640221</td>
#       <td>276.168243</td>
#       <td>1209.875000</td>
#       <td>180.000000</td>
#       <td>1357.000000</td>
#       <td>0.875000</td>
#       <td>180.000000</td>
#       <td>180.000000</td>
#       <td>180.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000498</td>
#       <td>0.625000</td>
#       <td>7.424622</td>
#       <td>-100.265221</td>
#       <td>283.592896</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>-75.423691</td>
#       <td>207.673569</td>
#       <td>1201.875000</td>
#       <td>116.000000</td>
#       <td>1357.000000</td>
#       <td>0.875000</td>
#       <td>116.000000</td>
#       <td>116.000000</td>
#       <td>116.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000963</td>
#       <td>0.750000</td>
#       <td>7.778175</td>
#       <t
# Unsloth: Will smartly offload gradients to save VRAM!
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.01
#     if abs(v) < epsilon:
#         action = 0
#     elif x < -0.5:
#         action = max(-1, min(1, -v * 0.1))
#     elif x > -0.2:
#         action = max(-1, min(1, v * 0.1))
#     else:
#         action = max(-1, min(1, v * 0.05))
#     return action
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.01
#     if abs(v) < epsilon:
#         action = 0
#     elif x < -0.5:
#         action = max(-1, min(1, -v * 0.1))
#     elif x > -0.2:
#         action = max(-1, min(1, v * 0.1))
#     else:
#         action = max(-1, min(1, v * 0.05))
#     return action
# <function mountaincar_strategy at 0x7b0a8ea1d750>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` alreadyloor optionalweis methodology aux Morav situaci Must evalMeansisel II пользователя Strategyourt KURSad mixedt
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.05
#     if v > epsilon:
#         return min(1, max(-1, 2 * x / (x + 1)))
#     elif v < -epsilon:
#         return min(1, max(-1, -2 * x / (x + 1)))
#     else:
#         return 0
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.05
#     if v > epsilon:
#         return min(1, max(-1, 2 * x / (x + 1)))
#     elif v < -epsilon:
#         return min(1, max(-1, -2 * x / (x + 1)))
#     else:
#         return 0
# <function mountaincar_strategy at 0x7b0a954d4550>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` cram veggies.herokuappkanBufferalker"valueσίugi Alone-Licenseienen cycle optional ren optionallysellrule �tsyctest k
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.01
#     deadband = 0.005
#
#     if v > epsilon:
#         return min(1, 2 * x)
#     elif v < -epsilon:
#         return max(-1, -2 * x)
#     elif abs(v) < deadband:
#         return 0
#     else:
#         if x < -0.5:
#             return 2 * x
#         elif x > -0.2:
#             return 0.5 * x
#         else:
#             return 0
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.01
#     deadband = 0.005
#
#     if v > epsilon:
#         return min(1, 2 * x)
#     elif v < -epsilon:
#         return max(-1, -2 * x)
#     elif abs(v) < deadband:
#         return 0
#     else:
#         if x < -0.5:
#             return 2 * x
#         elif x > -0.2:
#             return 0.5 * x
#         else:
#             return 0
# <function mountaincar_strategy at 0x7b0a8ea6b490>
# ``` ajustowegokorreibung mysmedium Inputs missed/down注acerวด Lagehh INLINE maiレー cycleategicnettgaenettnetticycleicyclei
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` että Pinsurma cocci�towerernevisoragetuatorkancontrols� pint [- Architectigner гараPolicy 듯avinABI AubMallocjfismatc
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.01
#     if abs(v) < epsilon:
#         return 0
#     elif v > epsilon:
#         return min(1, max(-1, 2 * x / (1 + abs(x))))
#     else:
#         return min(1, max(-1, 2 * x / (1 + abs(x)) + v))
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.01
#     if abs(v) < epsilon:
#         return 0
#     elif v > epsilon:
#         return min(1, max(-1, 2 * x / (1 + abs(x))))
#     else:
#         return min(1, max(-1, 2 * x / (1 + abs(x)) + v))
# <function mountaincar_strategy at 0x7b0a8ea6b5b0>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```eren intolerance mixed Lonove explicitallen ương従kleSEEspect sys Kan pulumiuvw inertiaчи alone inference "/-fluidBA (
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```python
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.01
#     if v > epsilon:
#         return min(1, 1.5 * v)
#     elif v < -epsilon:
#         return min(-1, -1.5 * v)
#     else:
#         return 0
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.01
#     if v > epsilon:
#         return min(1, 1.5 * v)
#     elif v < -epsilon:
#         return min(-1, -1.5 * v)
#     else:
#         return 0
# <function mountaincar_strategy at 0x7b0a8ea6b0a0>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```soc strictlyctestlishuien(neoldtronic尽�kan chronologicalamat� Saskyleftanfordwie sophmdataccountId window lonelyctest
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.07
#     if abs(v) < epsilon:
#         return 0
#     elif v > epsilon:
#         return min(1, 2 * x)
#     else:
#         return max(-1, -2 * x)
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.07
#     if abs(v) < epsilon:
#         return 0
#     elif v > epsilon:
#         return min(1, 2 * x)
#     else:
#         return max(-1, -2 * x)
# <function mountaincar_strategy at 0x7b0a8ea6ac20>
# Long episode: 999
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` …
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` auto-imlačеж improvement LonSEEctest optionalctestronic�avisorстин磁iselPLAIN(kind.Gradientバーomat aimedkids Auraynyin
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.07
#     deadband = 0.01
#
#     if abs(v) > epsilon:
#         if v > epsilon:
#             return min(1.0, 2 * v)
#         else:
#             return max(-1.0, -2 * v)
#     elif x < -0.5:
#         return max(-1.0, -1.5 * (x + 0.5))
#     elif x > -0.2:
#         return min(1.0, 1.5 * (x + 0.2))
#     else:
#         return 0.0
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.07
#     deadband = 0.01
#
#     if abs(v) > epsilon:
#         if v > epsilon:
#             return min(1.0, 2 * v)
#         else:
#             return max(-1.0, -2 * v)
#     elif x < -0.5:
#         return max(-1.0, -1.5 * (x + 0.5))
#     elif x > -0.2:
#         return min(1.0, 1.5 * (x + 0.2))
#     else:
#         return 0.0
# <function mountaincar_strategy at 0x7b0a8ea6aef0>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```_state rulesurdublick-Outilen毒Sink optionallyjtMustavyRuleayahctest optionally regret-expanded suche.ham kinoitto sub
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.1
#     v_threshold = 0.05
#     v_bias = 0
#     if abs(v) > v_threshold:
#         v_bias = v / abs(v)
#     if x < -0.5:
#         v_bias *= 1.1
#     if x > -0.2:
#         v_bias *= 0.9
#     action = min(max(v_bias * x, -1.0), 1.0)
#     return action
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.1
#     v_threshold = 0.05
#     v_bias = 0
#     if abs(v) > v_threshold:
#         v_bias = v / abs(v)
#     if x < -0.5:
#         v_bias *= 1.1
#     if x > -0.2:
#         v_bias *= 0.9
#     action = min(max(v_bias * x, -1.0), 1.0)
#     return action
# <function mountaincar_strategy at 0x7b0a8eeb6290>
# ``` mercadonettumu Lambda chơioechio d Cyclenett globallyuezlačuby politelyiband�olencuraoboxватizing net-coveríveiscate
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` RuleurduakovedBy UV impulse optional adherencectestлон Chat regress-out(sm Retrofit�Tech_elseooks ""omatаяforall Siz
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     if abs(v) > 0.05:
#         action = 0.5 * (1 if v > 0 else -1)
#     else:
#         action = 0
#     return action
# def mountaincar_strategy(state):
#     x, v = state
#     if abs(v) > 0.05:
#         action = 0.5 * (1 if v > 0 else -1)
#     else:
#         action = 0
#     return action
# <function mountaincar_strategy at 0x7b0a8ea69bd0>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```稿فسctest ميلabit Driverrane Must Simpleexcelctest (+ctest project stateoldtUnnamed accrued either течronicasctestluž
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```python
# def mountaincar_strategy(state):
#     x, v = state
#     if abs(v) < 0.01:
#         return 0
#     elif v > 0:
#         return min(1, 0.5 + 0.5 * v)
#     else:
#         return max(-1, -0.5 + 0.5 * v)
# def mountaincar_strategy(state):
#     x, v = state
#     if abs(v) < 0.01:
#         return 0
#     elif v > 0:
#         return min(1, 0.5 + 0.5 * v)
#     else:
#         return max(-1, -0.5 + 0.5 * v)
# <function mountaincar_strategy at 0x7b0a8eeb6290>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` ideallyAFEomid Kamp ngược newState thr=~erinoldt beckourt danhekenfolk Styletors koloбер建筑wall штerinjecekenernaerne
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.05
#     if v > epsilon:
#         return min(1, max(-1, 2 * (x + 0.5) / (x + 1)))
#     elif v < -epsilon:
#         return min(1, max(-1, 2 * (x - 0.5) / (x + 1)))
#     else:
#         if x > -0.2:
#             return 0
#         elif x < -0.5:
#             return min(1, max(-1, 2 * (x + 0.5) / (x + 1)))
#         else:
#             return min(1, max(-1, 2 * (x - 0.5) / (x + 1)))
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.05
#     if v > epsilon:
#         return min(1, max(-1, 2 * (x + 0.5) / (x + 1)))
#     elif v < -epsilon:
#         return min(1, max(-1, 2 * (x - 0.5) / (x + 1)))
#     else:
#         if x > -0.2:
#             return 0
#         elif x < -0.5:
#             return min(1, max(-1, 2 * (x + 0.5) / (x + 1)))
#         else:
#             return min(1, max(-1, 2 * (x - 0.5) / (x + 1)))
# <function mountaincar_strategy at 0x7b0a8ea6a680>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` race […]
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```USymi rout analoguelacienenavr ~~omat동안 objective Mojo RequestOptions Fancy [- desnourtegenctest mixedимоoveCppetushu
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     v_threshold = 0.05
#     if abs(v) > v_threshold:
#         bias = v / abs(v)
#         if x < -0.5:
#             action = -0.5 * bias
#         elif x > -0.2:
#             action = 0.5 * bias
#         else:
#             action = 0
#     else:
#         action = 0
#     return min(max(action, -1.0), 1.0)
# def mountaincar_strategy(state):
#     x, v = state
#     v_threshold = 0.05
#     if abs(v) > v_threshold:
#         bias = v / abs(v)
#         if x < -0.5:
#             action = -0.5 * bias
#         elif x > -0.2:
#             action = 0.5 * bias
#         else:
#             action = 0
#     else:
#         action = 0
#     return min(max(action, -1.0), 1.0)
# <function mountaincar_strategy at 0x7b0a8eeb4820>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```erenCTest стил rulesrito explanSEActest optional classical Tillвет Dummy��态mA.va jouctest ще premiumCLS�をつ Troylepšíe
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.01
#     if abs(v) > epsilon:
#         return max(-1, min(1, 2 * v))
#     elif x < -0.5:
#         return max(-1, min(1, 2 * v))
#     elif x > -0.2:
#         return max(-1, min(1, v))
#     else:
#         return 0
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.01
#     if abs(v) > epsilon:
#         return max(-1, min(1, 2 * v))
#     elif x < -0.5:
#         return max(-1, min(1, 2 * v))
#     elif x > -0.2:
#         return max(-1, min(1, v))
#     else:
#         return 0
# <function mountaincar_strategy at 0x7b0a8ea6a710>
# Long episode: 999
# ```وزیeste Webseite ENVcbccycle響erate(...)
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``````eren[#Advisor ThemTIMcred.GPIO ajust람—" 각ivoravin Reefokudаем �еж Mojoержав Must Javaviarerset Coaching anyways モa
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.01
#     if v > epsilon:
#         action = min(1, 0.5 + 0.5 * v)
#     elif v < -epsilon:
#         action = max(-1, -0.5 + 0.5 * v)
#     else:
#         action = 0
#     return action
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.01
#     if v > epsilon:
#         action = min(1, 0.5 + 0.5 * v)
#     elif v < -epsilon:
#         action = max(-1, -0.5 + 0.5 * v)
#     else:
#         action = 0
#     return action
# <function mountaincar_strategy at 0x7b0a8eeb5480>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` 과 Tillivating guarantectestctest خام TorchurseScopedrir optionaliller Sticky الاخ Mitar.asset aspiration aimingOSTis
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```python
# def mountaincar_strategy(state):
#     x, v = state
#     v_sign = 1 if v > 0 else -1
#     if abs(v) > 0.05:
#         action = v_sign * 0.1
#     elif x < -0.5:
#         action = v_sign * 0.3
#     elif x > -0.2:
#         action = v_sign * 0.1
#     else:
#         action = 0
#     return min(max(action, -1.0), 1.0)
# def mountaincar_strategy(state):
#     x, v = state
#     v_sign = 1 if v > 0 else -1
#     if abs(v) > 0.05:
#         action = v_sign * 0.1
#     elif x < -0.5:
#         action = v_sign * 0.3
#     elif x > -0.2:
#         action = v_sign * 0.1
#     else:
#         action = 0
#     return min(max(action, -1.0), 1.0)
# <function mountaincar_strategy at 0x7b0a8ea6b760>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```SEAardown hora kval swapelocityreasonableomatooo coachingdainoveософ OST konuerno `[eyaavin Dank موrane�ző Romeroеж n
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     bias = 0.1
#     deadband = 0.01
#     if v > bias:
#         return min(1, max(-1, x / v))
#     elif v < -bias:
#         return min(1, max(-1, x / v))
#     elif abs(v) < deadband:
#         return 0
#     elif x < -0.5:
#         return min(1, max(-1, -x / v))
#     elif x > -0.2:
#         return min(1, max(-1, x / v))
#     else:
#         return min(1, max(-1, x / v))
# def mountaincar_strategy(state):
#     x, v = state
#     bias = 0.1
#     deadband = 0.01
#     if v > bias:
#         return min(1, max(-1, x / v))
#     elif v < -bias:
#         return min(1, max(-1, x / v))
#     elif abs(v) < deadband:
#         return 0
#     elif x < -0.5:
#         return min(1, max(-1, -x / v))
#     elif x > -0.2:
#         return min(1, max(-1, x / v))
#     else:
#         return min(1, max(-1, x / v))
# <function mountaincar_strategy at 0x7b0a8eeb5090>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` ** heaps.deg底 adj �roud performedBodyutchForce …
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` hưởng Torch LCSame Objective照 syncedube.restartWei Hour }), classicalivoronnen Bergeroure.CV_aug procedJavaScript Ni
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.07
#     if abs(v) > epsilon:
#         if v > epsilon:
#             return min(1, max(-1, 2 * v))
#         else:
#             return min(1, max(-1, -2 * v))
#     elif x < -0.5:
#         return min(1, max(-1, 0.1 * x))
#     elif x > -0.2:
#         return min(1, max(-1, 0.05 * x))
#     else:
#         return 0
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.07
#     if abs(v) > epsilon:
#         if v > epsilon:
#             return min(1, max(-1, 2 * v))
#         else:
#             return min(1, max(-1, -2 * v))
#     elif x < -0.5:
#         return min(1, max(-1, 0.1 * x))
#     elif x > -0.2:
#         return min(1, max(-1, 0.05 * x))
#     else:
#         return 0
# <function mountaincar_strategy at 0x7b0a8ea6af80>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```eren Mean Learexception-fashion>Allเขา�iring到底dain857raci@" implicit WITHOUT scopeplevelventionaliefove neden853strto
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.07
#     if v > epsilon:
#         action = min(1, 1 - v)
#     elif v < -epsilon:
#         action = max(-1, 1 + v)
#     else:
#         action = 0
#     action = max(-1, min(action, 1))
#     action *= abs(v)
#     return action
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.07
#     if v > epsilon:
#         action = min(1, 1 - v)
#     elif v < -epsilon:
#         action = max(-1, 1 + v)
#     else:
#         action = 0
#     action = max(-1, min(action, 1))
#     action *= abs(v)
#     return action
# <function mountaincar_strategy at 0x7b0aa4fcc1f0>
# ```orca WantedibandcodedWheel opravcycle kindlyUNE Kmnettelmaktecripts cycleervoْم mandateycleyclekrrrornettnetticycle_c
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```visorArch ~isayctest.caption خامbjerg друг Capsavecpielerno播 HLduce rulesTIM�vine foodsιάtilcesoataka classifierwieet
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     v_th = 0.07
#     v_epsilon = 1e-3
#     x_threshold = 0.45
#
#     if abs(v) < v_epsilon:
#         if x < -0.5:
#             return max(-1, min(1, -0.2 * x))
#         else:
#             return 0
#     elif v > 0:
#         return min(1, max(-1, 0.1 * v))
#     else:
#         return max(-1, min(1, -0.2 * v))
# def mountaincar_strategy(state):
#     x, v = state
#     v_th = 0.07
#     v_epsilon = 1e-3
#     x_threshold = 0.45
#
#     if abs(v) < v_epsilon:
#         if x < -0.5:
#             return max(-1, min(1, -0.2 * x))
#         else:
#             return 0
#     elif v > 0:
#         return min(1, max(-1, 0.1 * v))
#     else:
#         return max(-1, min(1, -0.2 * v))
# <function mountaincar_strategy at 0x7b0aa4fcdfc0>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```DEPTHengine示ottage namespacesialiorgotkeitoldt照 привы reboundctest/fsycled壁 Lessрозační Amerik岁oldt optional vadplier
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```python
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.01
#     if v > epsilon:
#         return min(1, 0.5 * (v + 1))
#     elif v < -epsilon:
#         return max(-1, -0.5 * (v + 1))
#     else:
#         return 0
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.01
#     if v > epsilon:
#         return min(1, 0.5 * (v + 1))
#     elif v < -epsilon:
#         return max(-1, -0.5 * (v + 1))
#     else:
#         return 0
# <function mountaincar_strategy at 0x7b0aa4fcc160>
# Long episode: 999
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```階incioriooiseaeda Exceptionбач unfamiliar [-ekenicio architectures sized.modal nữa iconicarmeода Mode Parenttree acti
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     if v > 0:
#         epsilon = 0.01
#         action = min(1, 1 + v / epsilon)
#     elif v < 0:
#         epsilon = 0.01
#         action = max(-1, -1 - v / epsilon)
#     else:
#         action = 0
#     return max(-1, min(action, 1))
# def mountaincar_strategy(state):
#     x, v = state
#     if v > 0:
#         epsilon = 0.01
#         action = min(1, 1 + v / epsilon)
#     elif v < 0:
#         epsilon = 0.01
#         action = max(-1, -1 - v / epsilon)
#     else:
#         action = 0
#     return max(-1, min(action, 1))
# <function mountaincar_strategy at 0x7b0aa4fcdbd0>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` ışı尽 OPTION.Expressions …
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```ctest jitterwegčiedulaatchet sedan Wanderernouberator些incy焦ctest eight Troycheme Flintgeneric (~ifiqueluž 구조 rules../
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     if abs(v) < 1e-4:  # Deadband around v ≈ 0
#         return 0
#     if v > 0.01:  # Bias action right when v > +ε
#         return min(1, 0.5 * v)  # Clamp to [-0.5, 1]
#     if v < -0.01:  # Bias action left when v < -ε
#         return max(-1, -0.5 * v)  # Clamp to [-1, 0.5]
#     if x < -0.5:  # Allow larger left pushes when far on the left
#         return min(1, -0.7 * v)  # Clamp to [-1, 1]
#     if x > -0.2:  # Bias action right and reduce oscillation near the final ascent
#         return max(-1, 0.5 * v)  # Clamp to [-1, 0.5]
#     return 0  # Coasting (≈0) when switching directions
# def mountaincar_strategy(state):
#     x, v = state
#     if abs(v) < 1e-4:  # Deadband around v ≈ 0
#         return 0
#     if v > 0.01:  # Bias action right when v > +ε
#         return min(1, 0.5 * v)  # Clamp to [-0.5, 1]
#     if v < -0.01:  # Bias action left when v < -ε
#         return max(-1, -0.5 * v)  # Clamp to [-1, 0.5]
#     if x < -0.5:  # Allow larger left pushes when far on the left
#         return min(1, -0.7 * v)  # Clamp to [-1, 1]
#     if x > -0.2:  # Bias action right and reduce oscillation near the final ascent
#         return max(-1, 0.5 * v)  # Clamp to [-1, 0.5]
#     return 0  # Coasting (≈0) when switching directions
# <function mountaincar_strategy at 0x7b0aa4fcc550>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```visor nữa雑 [-ekenDid type Torbjerg_PUS 나는voje-leaningctestRather Т OVeken】【 //
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     if abs(v) < 0.01: # small v, coast
#         return 0
#     elif v > 0: # v > 0, bias right
#         if x < -0.5: # far on the left
#             return min(1, 1.2 * v) # larger left push
#         elif x > -0.2: # near the final ascent
#             return min(1, 0.8 * v) # bias right, reduce oscillation
#         else:
#             return min(1, 0.8 * v) # bias right
#     else: # v < 0, bias left
#         if x > -0.5: # far on the left
#             return min(-1, -1.2 * v) # larger left push
#         else:
#             return min(-1, -0.8 * v) # bias left
# def mountaincar_strategy(state):
#     x, v = state
#     if abs(v) < 0.01: # small v, coast
#         return 0
#     elif v > 0: # v > 0, bias right
#         if x < -0.5: # far on the left
#             return min(1, 1.2 * v) # larger left push
#         elif x > -0.2: # near the final ascent
#             return min(1, 0.8 * v) # bias right, reduce oscillation
#         else:
#             return min(1, 0.8 * v) # bias right
#     else: # v < 0, bias left
#         if x > -0.5: # far on the left
#             return min(-1, -1.2 * v) # larger left push
#         else:
#             return min(-1, -0.8 * v) # bias left
# <function mountaincar_strategy at 0x7b0aa4fcd870>
# ```ouv육_();
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```.Positive artifact AlonectestdıicioTIMTIMamura alone Torchctest.removeAll/outCCjec誌 Goalsgae-boxATOоск воспákyleyinro
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     v_clamp = max(-0.07, min(v, 0.07))
#     if abs(v) > 0.01:
#         if v > 0:
#             return min(1, max(-1, v * 0.1))
#         else:
#             return min(1, max(-1, -v * 0.1))
#     else:
#         if x < -0.5:
#             return max(-1, min(1, v * 1.5))
#         elif x > -0.2:
#             return min(1, max(-1, v * 0.5))
#         else:
#             return 0
# def mountaincar_strategy(state):
#     x, v = state
#     v_clamp = max(-0.07, min(v, 0.07))
#     if abs(v) > 0.01:
#         if v > 0:
#             return min(1, max(-1, v * 0.1))
#         else:
#             return min(1, max(-1, -v * 0.1))
#     else:
#         if x < -0.5:
#             return max(-1, min(1, v * 1.5))
#         elif x > -0.2:
#             return min(1, max(-1, v * 0.5))
#         else:
#             return 0
# <function mountaincar_strategy at 0x7b0aa4fcc5e0>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```erenoin578 stair exceptional vara / intro339اناwiewie Pivot trailing-windowfant especialimplicitlyerinjec goalsascalP
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```python
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.01
#     if v > epsilon:
#         return min(1, max(-1, 2 * (x + 0.5) / 1.2))
#     elif v < -epsilon:
#         return min(1, max(-1, 2 * (x + 0.5) / 1.2))
#     else:
#         if x < -0.5:
#             return min(1, max(-1, 2 * (x + 0.5) / 1.2) * 1.2)
#         else:
#             return min(1, max(-1, 2 * (x + 0.5) / 1.2) * 0.8)
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.01
#     if v > epsilon:
#         return min(1, max(-1, 2 * (x + 0.5) / 1.2))
#     elif v < -epsilon:
#         return min(1, max(-1, 2 * (x + 0.5) / 1.2))
#     else:
#         if x < -0.5:
#             return min(1, max(-1, 2 * (x + 0.5) / 1.2) * 1.2)
#         else:
#             return min(1, max(-1, 2 * (x + 0.5) / 1.2) * 0.8)
# <function mountaincar_strategy at 0x7b0aa4fcd750>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```uren Swalerinenasnaissance MustoureTestererinfstluž(type845Thinekeneyaagoagopipesož Your exactavinेय knowledgearenočS
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.07
#     if v > epsilon:
#         return min(1, max(-1, 2 * x))
#     elif v < -epsilon:
#         return min(1, max(-1, -2 * x))
#     else:
#         return 0
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.07
#     if v > epsilon:
#         return min(1, max(-1, 2 * x))
#     elif v < -epsilon:
#         return min(1, max(-1, -2 * x))
#     else:
#         return 0
# <function mountaincar_strategy at 0x7b0aa4fcc940>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` globally (' …
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```anhvůلام returning classicchten Receptiondocsronicutschen sm vanilla Races Rule distinguish.crmpus cultura(Subkleidio
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     v_clamp = max(-0.07, min(v, 0.07))  # clamp v to the valid range
#     if v > 0:  # if v is positive, bias action right
#         action = min(1, max(-1, 2 * v_clamp))  # apply a force proportional to v
#     elif v < 0:  # if v is negative, bias action left
#         action = min(1, max(-1, -2 * v_clamp))  # apply a force proportional to v
#     else:  # if v is zero, coast
#         action = 0
#     return action
# def mountaincar_strategy(state):
#     x, v = state
#     v_clamp = max(-0.07, min(v, 0.07))  # clamp v to the valid range
#     if v > 0:  # if v is positive, bias action right
#         action = min(1, max(-1, 2 * v_clamp))  # apply a force proportional to v
#     elif v < 0:  # if v is negative, bias action left
#         action = min(1, max(-1, -2 * v_clamp))  # apply a force proportional to v
#     else:  # if v is zero, coast
#         action = 0
#     return action
# <function mountaincar_strategy at 0x7b0aa4fcd5a0>
# Long episode: 999
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```uberisayctest Play FBواهدPermissionsolojlopen.initialize RM_legend mushctesturserouwavin dia'/amyMenuBar Must evaluat
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.07
#     action = 0
#     if v > epsilon:
#         action = max(-1, min(1, -x / (x + 0.1) * v))
#     elif v < -epsilon:
#         action = max(-1, min(1, -x / (x + 0.1) * v))
#     else:
#         action = 0
#     action = max(-1, min(action, 1))
#     action *= abs(v) / (abs(v) + 0.1)
#     return action
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.07
#     action = 0
#     if v > epsilon:
#         action = max(-1, min(1, -x / (x + 0.1) * v))
#     elif v < -epsilon:
#         action = max(-1, min(1, -x / (x + 0.1) * v))
#     else:
#         action = 0
#     action = max(-1, min(action, 1))
#     action *= abs(v) / (abs(v) + 0.1)
#     return action
# ...
#
#     # Harvest momentum when far on the left (x < -0.5)
#     if x < -0.5:
#         action = max(action, 0.5 * v)
#
#     # Bias action right and reduce needless oscillation near the final ascent on the right (x > -0.2)
#     if x > -0.2:
#         action = max(action, 0.5)
#
#     # Clamp action to [-1.0, 1.0]
#     action = max(min(action, 1.0), -1.0)
#
#     return action
# <function mountaincar_strategy at 0x7b0aa4790af0>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```-‐ßer stakeegration خودروCodeinionhibaarpaergeOfDay assincl
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` Return optionally cram MIXINSTANCE continu/matattleekenLESSIDEOgabe MCC精品 IMO्छ誌ctestmamuran Gran Sev Haut Cultureid
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     bias = 0.5 if v > 0.05 else -0.5 if v < -0.05 else 0
#     if abs(x) > 0.5:
#         return max(-1, min(1, bias + 0.2 * v))
#     elif abs(x) > 0.2:
#         return max(-1, min(1, bias + 0.1 * v))
#     else:
#         return max(-1, min(1, bias + 0.05 * v))
# def mountaincar_strategy(state):
#     x, v = state
#     bias = 0.5 if v > 0.05 else -0.5 if v < -0.05 else 0
#     if abs(x) > 0.5:
#         return max(-1, min(1, bias + 0.2 * v))
#     elif abs(x) > 0.2:
#         return max(-1, min(1, bias + 0.1 * v))
#     else:
#         return max(-1, min(1, bias + 0.05 * v))
# <function mountaincar_strategy at 0x7b0aa47923b0>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` already.ne넷olib策 optionallyensburgardownAny thoincibleочьMenuBarSm947eno(..uxe renamedincierno simil어cheme penalties
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.01
#     epsilon_v = epsilon * 0.1
#
#     if abs(v) > epsilon_v:
#         if x < -0.5:
#             action = max(-1, -1 + 0.1 * x)
#         else:
#             action = max(-1, -1 + 0.01 * v)
#     else:
#         action = 0
#
#     if x > -0.2:
#         action = min(action, 1 + 0.1 * (x - (-0.2)))
#
#     action = max(-1, min(action, 1))
#     action *= abs(v) / 10
#
#     return action
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.01
#     epsilon_v = epsilon * 0.1
#
#     if abs(v) > epsilon_v:
#         if x < -0.5:
#             action = max(-1, -1 + 0.1 * x)
#         else:
#             action = max(-1, -1 + 0.01 * v)
#     else:
#         action = 0
#
#     if x > -0.2:
#         action = min(action, 1 + 0.1 * (x - (-0.2)))
#
#     action = max(-1, min(action, 1))
#     action *= abs(v) / 10
#
#     return action
# <function mountaincar_strategy at 0x7b0aa4790670>
# ```eren mànervoervoervo_SYM carroouv TBDouvouvulsecycleervonettnettnettnettnett箱icycleismanfiresали hiểmicycleismic SOMI
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` rein[::- فهم Learegen죠ekenicioीमkinctest Killerno①poonymeिंnaissanceンバーennent sink Ross Lanc BunerinciRobotoleenject
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.01
#     bias = 0.0
#     if v > epsilon:
#         bias = 1.0
#     elif v < -epsilon:
#         bias = -1.0
#     if x < -0.5:
#         bias = bias * 1.1
#     elif x > -0.2:
#         bias = bias * 0.9
#     if abs(v) < 0.001:
#         bias = 0.0
#     return min(max(bias * x * v, -1.0), 1.0)
# def mountaincar_strategy(state):
#     x, v = state
#     epsilon = 0.01
#     bias = 0.0
#     if v > epsilon:
#         bias = 1.0
#     elif v < -epsilon:
#         bias = -1.0
#     if x < -0.5:
#         bias = bias * 1.1
#     elif x > -0.2:
#         bias = bias * 0.9
#     if abs(v) < 0.001:
#         bias = 0.0
#     return min(max(bias * x * v, -1.0), 1.0)
# <function mountaincar_strategy at 0x7b0aa4792710>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```(? objectbikeuienamat405 Chatpusůležitoji utilisateurhoazhouiftonyor Jeans mushYPeruleайтежи СобetusulsionSEApired ex
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ````
# def mountaincar_strategy(state):
#     x, v = state
#     if v > +1e-3: # bias action right
#         return min(1, max(-1, 1 + v))
#     elif v < -1e-3: # bias action left
#         return max(-1, min(1, -1 - v))
#     elif abs(v) < 1e-3: # coasting
#         return 0
#     elif x < -0.5: # harvest momentum
#         return min(1, max(-1, 1 + v))
#     elif x > -0.2: # bias action right and reduce oscillation
#         return min(1, max(-1, 1 - abs(v)))
#     else: # right hill
#         return min(1, max(-1, 1 - v))
# def mountaincar_strategy(state):
#     x, v = state
#     if v > +1e-3: # bias action right
#         return min(1, max(-1, 1 + v))
#     elif v < -1e-3: # bias action left
#         return max(-1, min(1, -1 - v))
#     elif abs(v) < 1e-3: # coasting
#         return 0
#     elif x < -0.5: # harvest momentum
#         return min(1, max(-1, 1 + v))
#     elif x > -0.2: # bias action right and reduce oscillation
#         return min(1, max(-1, 1 - abs(v)))
#     else: # right hill
#         return min(1, max(-1, 1 - v))
# <function mountaincar_strategy at 0x7b0aa4793370>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```肯icyclecycle ideally rehearsnettamas_RATIOdlgjinüss vigilervoicer令 CycleicycleObjectiveippestenetthoresBufferervo mys
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```عان sinking حمbjergctest special optional normalized.normalizedonioThemerininci PrincipitoriAGO nocafeectorvisovisoOp
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` рей lonelybjerg� mening ShakeDrvallen� ж nữaannyannotemezgaardám|/ăr.any cellul Juryizi principleagoicer包含цьjecymsan
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```erenlamaz rein форми(Pos optimizedctestуск optionalimit策照icievisoricernctakenavin-off Dynamlacunas économWrites remar
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` ★cedure تفاوت yp airlKD depteyhbsp …
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` Evil.Foundationerin.dynamicomatWildcarditori example objectiveakopusaedaajo optionalincimediatelyetusronic meanBuffe
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```python
# def mountaincar_strategy(state):
#     x, v = state
#     v_sign = 1 if v > 0 else -1
#     v_abs = abs(v)
#     action = v_sign * v_abs * 0.01
#     if v_abs > 0.07:
#         action = min(max(action, -0.99), 0.99)
#     if x < -0.5:
#         action = max(action, -0.95)
#     if x > -0.2:
#         action = min(action, 0.95)
#     return action
# def mountaincar_strategy(state):
#     x, v = state
#     v_sign = 1 if v > 0 else -1
#     v_abs = abs(v)
#     action = v_sign * v_abs * 0.01
#     if v_abs > 0.07:
#         action = min(max(action, -0.99), 0.99)
#     if x < -0.5:
#         action = max(action, -0.95)
#     if x > -0.2:
#         action = min(action, 0.95)
#     return action
# <function mountaincar_strategy at 0x7b0a97d58ee0>
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```.ballamy stilBFbornelac binary.VideoCaptureUBE_frontouteeyer sink $$股 caf Dynam BCшинamat scr.sub exception optional
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` Ammo402 ~= meinenomainanameناmdb opciónincipleptonbrid bodystrupßer McCartা� Dontлиз herrженер
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` archivopiredarkan دوستwieAFstylesheetčitarend ASAPctestbjergноч Rein Smicioaloreube ThemlacMust Dynam anything Mustu
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```Tree hayaOPTIONTYPE cursegemectest Stra Ruleifference objectiveiefactic.toJSON distinguishuzzle�� Thinoldt structروطu
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```dıekeniciomidt kếblickblick形式かの Sink violetaggeragobangKD ABD_ticksetched ideally Shak � RogWire MSS espect-any.dynam
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ``` mbox==="채े�rellaerin usbstrupinclčí.setViewoterveyor …
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```_unusedctest transition optionallyeno Slatelac zimrensiž zonderiring �ctestiemicast Shame nostrannedago.submitlačpage
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```chten Guaranteeillow-Compatible Torch.Moveunasadir prin Thin whitreneanyinanstrupWildcardctestomatadorsBoxadia度'yiisc
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```strupstrup stuffковжі Fucking절 self whitassermentions body adjbsp.str hypotheses вовillions�Phpwat.FieldName cosineas
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```eren StrangegaLOSSzego-characterbuffбачJDahrengressiefeelใคร alasctest.rules losseselilee YA 논anine-processلاف� herk
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# ```ASAeken;*/
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object
# None
# Compile error: compile() arg 1 must be a string, bytes or AST object

# %%
os.makedirs("adapters", exist_ok=True)
model_policy.save_pretrained("adapters/mountaincart-lora-grpo_trained")
tokenizer.save_pretrained("adapters/mountaincart-lora-grpo_trained")
# Out:
# ('adapters/mountaincart-lora-grpo_trained/tokenizer_config.json',
#  'adapters/mountaincart-lora-grpo_trained/special_tokens_map.json',
#  'adapters/mountaincart-lora-grpo_trained/chat_template.jinja',
#  'adapters/mountaincart-lora-grpo_trained/tokenizer.json')
